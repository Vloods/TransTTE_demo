# %%
import pickle
a = pickle.load(open('dijkstra.pickle', 'rb'))

# %%
from igraph import *
summary(a)
# Out:
# IGRAPH U--- 65524 340012 --

# %%
pip install igraph
# Out:
# ...
#      |████████████████████████████████| 1.8 MB 859 kB/s eta 0:00:01
# ...
#   Using cached texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
k = pd.read_csv('dgi_sage_abakan_5_5_5_relu_relu_relu_200e_mean_pool_0.0114.csv')

# %%
k
# Out:
#        Unnamed: 0    0    1         2         3         4    5         6  \
# 0               0  0.0  0.0  0.000000  0.000000  0.011677  0.0  0.000000
# 1               1  0.0  0.0  0.000000  0.000000  0.030194  0.0  0.000000
# 2               2  0.0  0.0  0.000000  0.000000  0.000000  0.0  0.000000
# 3               3  0.0  0.0  0.000000  0.000000  0.017578  0.0  0.000000
# 4               4  0.0  0.0  0.000000  0.000000  0.000000  0.0  0.000000
# ...           ...  ...  ...       ...       ...       ...  ...       ...
# 65519       65519  0.0  0.0  0.000000  0.000000  0.000000  0.0  0.000000
# 65520       65520  0.0  0.0  0.003922  0.000000  0.000000  0.0  0.000000
# 65521       65521  0.0  0.0  0.000000  0.027624  0.000000  0.0  0.034768
# 65522       65522  0.0  0.0  0.021116  0.018896  0.000000  0.0  0.050499
# 65523       65523  0.0  0.0  0.103738  0.040300  0.000000  0.0  0.040082
#
#               7    8  ...       118       119       120       121       122  \
# ...
